# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
fifa = pd.read_excel('F:/fifa_player.xlsx')
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi      Lionel AndrÃ©s Messi Cuccittini   27 1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29 1985-02-05
# 2          A. Robben                         Arjen Robben   30 1984-01-23
# 3    Z. IbrahimoviÄ‡                  Zlatan IbrahimoviÄ‡   32 1981-10-03
# 4           M. Neuer                         Manuel Neuer   28 1986-03-27
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# 0        169         67    Argentina         FC Barcelona  ...  62+3  62+3
# 1        185         80     Portugal          Real Madrid  ...  63+3  63+3
# 2        180         80  Netherlands   FC Bayern MÃ¼nchen  ...  64+3  64+3
# 3        195         95       Sweden  Paris Saint-Germain  ...  61+3  65+3
# 4        193         92      Germany   FC Bayern MÃ¼nchen  ...   NaN   NaN
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3
# 1  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 2  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3
# 3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
fifa.shape
# Out:
# (15465, 104)

# %%
15465*104 #total cells
# Out:
# 1608360

# %%
fifa['nationality'].value_counts()
# Out:
# England          1579
# Spain            1022
# France            875
# Argentina         861
# Italy             778
#                  ...
# Bahrain             1
# Guam                1
# Niger               1
# Oman                1
# Liechtenstein       1
# Name: nationality, Length: 148, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# England                1579
# Spain                  1022
# France                  875
# Argentina               861
# Italy                   778
# Germany                 695
# Colombia                517
# Republic of Ireland     453
# Mexico                  416
# Chile                   410
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1579
# Spain        1022
# France        875
# Argentina     861
# Italy         778
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()), fifa['nationality'].value_counts()[0:5])
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi         0
# 1  Cristiano Ronaldo         0
# 2          A. Robben         0
# 3    Z. IbrahimoviÄ‡         0
# 4           M. Neuer         0

# %%
player_salary = player_salary.sort_values(by = ['wage_eur'], ascending=False)
player_salary
# Out:
#            short_name  wage_eur
# 0            L. Messi         0
# 10270  A. EchavarrÃ­a         0
# 10302        A. Dawsh         0
# 10303          Cassio         0
# 10304       C. N'JiÃ©         0
# ...               ...       ...
# 5160       V. Kujovic         0
# 5161      R. Vitiello         0
# 5162        I. Castro         0
# 5163   C. Wilhelmsson         0
# 15464      P. Tisdale         0
#
# [15465 rows x 2 columns]

# %%
plt.figure(figsize=(8,7))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5], color=["blue", "yellow", "pink", "orange", "gray"])
plt.show()

# %%
# country info 

#Germany

# %%
Germany = fifa[fifa['nationality']== 'Germany']
Germany.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 4      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8      121944  https://sofifa.com/player/121944/bastian-schwe...
# 13     121939  https://sofifa.com/player/121939/philipp-lahm/...
# 21     178603  https://sofifa.com/player/178603/mats-hummels/...
# 23     188350  https://sofifa.com/player/188350/marco-reus/15...
# 24     189596  https://sofifa.com/player/189596/thomas-muller...
# 26     176635  https://sofifa.com/player/176635/mesut-ozil/15...
# 31     192318  https://sofifa.com/player/192318/mario-gotze/1...
# 33     182521  https://sofifa.com/player/182521/toni-kroos/15...
# 41     183907  https://sofifa.com/player/183907/jerome-boaten...
#
#            short_name               long_name  age        dob  height_cm  \
# 4            M. Neuer            Manuel Neuer   28 1986-03-27        193
# 8   B. Schweinsteiger  Bastian Schweinsteiger   29 1984-08-01        183
# 13            P. Lahm            Philipp Lahm   30 1983-11-11        170
# 21         M. Hummels           Mats  Hummels   25 1988-12-16        192
# 23            M. Reus              Marco Reus   25 1989-05-31        181
# 24         T. MÃ¼ller          Thomas MÃ¼ller   24 1989-09-13        186
# 26           M. Ã–zil             Mesut Ã–zil   25 1988-10-15        183
# 31          M. GÃ¶tze            Mario GÃ¶tze   22 1992-06-03        176
# 33           T. Kroos              Toni Kroos   24 1990-01-04        182
# 41         J. Boateng        JÃ©rÃ´me Boateng   25 1988-09-03        192
#
#     weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# 4          92     Germany  FC Bayern MÃ¼nchen  ...   NaN   NaN   NaN   NaN
# 8          79     Germany  FC Bayern MÃ¼nchen  ...  81+2  84+2  84+2  84+2
# 13         66     Germany  FC Bayern MÃ¼nchen  ...  88+2  85+2  85+2  85+2
# 21         90     Germany   Borussia Dortmund  ...  79+2  82+2  82+2  82+2
# 23         73     Germany   Borussia Dortmund  ...  64+1  63+1  63+1  63+1
# 24         75     Germany  FC Bayern MÃ¼nchen  ...  68+2  69+2  69+2  69+2
# 26         76     Germany             Arsenal  ...  59+1  62+1  62+1  62+1
# 31         72     Germany  FC Bayern MÃ¼nchen  ...  63+1  65+1  65+1  65+1
# 33         78     Germany         Real Madrid  ...  74+2  76+2  76+2  76+2
# 41         90     Germany  FC Bayern MÃ¼nchen  ...  78+2  77+2  77+2  77+2
#
#      rwb    lb   lcb    cb   rcb    rb
# 4    NaN   NaN   NaN   NaN   NaN   NaN
# 8   81+2  81+2  79+2  79+2  79+2  81+2
# 13  88+2  85+2  81+2  81+2  81+2  85+2
# 21  79+2  81+2  84+2  84+2  84+2  81+2
# 23  64+1  56+1  48+1  48+1  48+1  56+1
# 24  68+2  65+2  58+2  58+2  58+2  65+2
# 26  59+1  51+1  44+1  44+1  44+1  51+1
# 31  63+1  55+1  48+1  48+1  48+1  55+1
# 33  74+2  68+2  63+2  63+2  63+2  68+2
# 41  78+2  80+2  83+2  83+2  83+2  80+2
#
# [10 rows x 104 columns]

# %%
Germany.sort_values(by=['height_cm'], ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 8877     169223  https://sofifa.com/player/169223/thorsten-stuc...
# 8814     150389  https://sofifa.com/player/150389/benedikt-pliq...
# 2029     199833  https://sofifa.com/player/199833/lars-unnersta...
# 7642     200212  https://sofifa.com/player/200212/michael-esser...
# 79        53612  https://sofifa.com/player/53612/per-mertesacke...
#
#           short_name           long_name  age        dob  height_cm  \
# 8877    T. Stuckmann  Thorsten Stuckmann   33 1981-03-17        199
# 8814     B. Pliquett   Benedikt Pliquett   29 1984-12-20        199
# 2029   L. Unnerstall     Lars Unnerstall   23 1990-07-20        198
# 7642        M. Esser       Michael Esser   26 1987-11-22        198
# 79    P. Mertesacker     Per Mertesacker   29 1984-09-29        198
#
#       weight_kg nationality                 club  ...   lwb   ldm   cdm   rdm  \
# 8877         97     Germany    Preston North End  ...   NaN   NaN   NaN   NaN
# 8814         95     Germany        SK Sturm Graz  ...   NaN   NaN   NaN   NaN
# 2029        100     Germany  Fortuna DÃ¼sseldorf  ...   NaN   NaN   NaN   NaN
# 7642         97     Germany      VfL Bochum 1848  ...   NaN   NaN   NaN   NaN
# 79           90     Germany              Arsenal  ...  69+1  75+1  75+1  75+1
#
#        rwb    lb   lcb    cb   rcb    rb
# 8877   NaN   NaN   NaN   NaN   NaN   NaN
# 8814   NaN   NaN   NaN   NaN   NaN   NaN
# 2029   NaN   NaN   NaN   NaN   NaN   NaN
# 7642   NaN   NaN   NaN   NaN   NaN   NaN
# 79    69+1  75+1  82+1  82+1  82+1  75+1
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['weight_kg'], ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 1745       53012  https://sofifa.com/player/53012/tim-wiese/15/1...
# 2029      199833  https://sofifa.com/player/199833/lars-unnersta...
# 8877      169223  https://sofifa.com/player/169223/thorsten-stuc...
# 7642      200212  https://sofifa.com/player/200212/michael-esser...
# 13726     224251  https://sofifa.com/player/224251/robin-zentner...
#
#           short_name           long_name  age        dob  height_cm  \
# 1745        T. Wiese           Tim Wiese   32 1981-12-17        193
# 2029   L. Unnerstall     Lars Unnerstall   23 1990-07-20        198
# 8877    T. Stuckmann  Thorsten Stuckmann   33 1981-03-17        199
# 7642        M. Esser       Michael Esser   26 1987-11-22        198
# 13726     R. Zentner       Robin Zentner   19 1994-10-28        194
#
#        weight_kg nationality                 club  ...  lwb  ldm  cdm  rdm  \
# 1745         110     Germany  TSG 1899 Hoffenheim  ...  NaN  NaN  NaN  NaN
# 2029         100     Germany  Fortuna DÃ¼sseldorf  ...  NaN  NaN  NaN  NaN
# 8877          97     Germany    Preston North End  ...  NaN  NaN  NaN  NaN
# 7642          97     Germany      VfL Bochum 1848  ...  NaN  NaN  NaN  NaN
# 13726         96     Germany      1. FSV Mainz 05  ...  NaN  NaN  NaN  NaN
#
#        rwb   lb  lcb   cb  rcb   rb
# 1745   NaN  NaN  NaN  NaN  NaN  NaN
# 2029   NaN  NaN  NaN  NaN  NaN  NaN
# 8877   NaN  NaN  NaN  NaN  NaN  NaN
# 7642   NaN  NaN  NaN  NaN  NaN  NaN
# 13726  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['wage_eur'], ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 4        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 9003     223271  https://sofifa.com/player/223271/sinan-kurt/15...
# 8845     162010  https://sofifa.com/player/162010/sezer-ozturk/...
# 8877     169223  https://sofifa.com/player/169223/thorsten-stuc...
# 8935     191226  https://sofifa.com/player/191226/daniel-schulz...
#
#         short_name           long_name  age        dob  height_cm  weight_kg  \
# 4         M. Neuer        Manuel Neuer   28 1986-03-27        193         92
# 9003       S. Kurt          Sinan Kurt   17 1996-07-23        173         68
# 8845   S. Ã–ztÃ¼rk      Sezer Ã–ztÃ¼rk   28 1985-11-03        176         74
# 8877  T. Stuckmann  Thorsten Stuckmann   33 1981-03-17        199         97
# 8935     D. Schulz       Daniel Schulz   28 1986-02-21        192         90
#
#      nationality                     club  ...   lwb   ldm   cdm   rdm   rwb  \
# 4        Germany       FC Bayern MÃ¼nchen  ...   NaN   NaN   NaN   NaN   NaN
# 9003     Germany       FC Bayern MÃ¼nchen  ...  47+0  43+0  43+0  43+0  47+0
# 8845     Germany  Medipol BaÅŸakÅŸehir FK  ...  60+0  60+0  60+0  60+0  60+0
# 8877     Germany        Preston North End  ...   NaN   NaN   NaN   NaN   NaN
# 8935     Germany            SV Sandhausen  ...  52+0  57+0  57+0  57+0  52+0
#
#         lb   lcb    cb   rcb    rb
# 4      NaN   NaN   NaN   NaN   NaN
# 9003  39+0  33+0  33+0  33+0  39+0
# 8845  58+0  54+0  54+0  54+0  58+0
# 8877   NaN   NaN   NaN   NaN   NaN
# 8935  58+0  63+0  63+0  63+0  58+0
#
# [5 rows x 104 columns]

# %%
Germany[['short_name', 'wage_eur']].sort_values(by=['wage_eur'], ascending=False).head()
# Out:
#         short_name  wage_eur
# 4         M. Neuer         0
# 9003       S. Kurt         0
# 8845   S. Ã–ztÃ¼rk         0
# 8877  T. Stuckmann         0
# 8935     D. Schulz         0

# %%
# shooting

# %%
player_shooting =fifa[['short_name', 'shooting']]
player_shooting.sort_values(by=['shooting'], ascending = False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 3     Z. IbrahimoviÄ‡      91.0
# 7       R. van Persie      90.0
# 0            L. Messi      89.0
# 29          W. Rooney      87.0

# %%
# Defending

# %%
player_defending = fifa[['short_name', 'defending', 'nationality', 'club']]
player_defending.head()
# Out:
#           short_name  defending  nationality                 club
# 0           L. Messi       27.0    Argentina         FC Barcelona
# 1  Cristiano Ronaldo       32.0     Portugal          Real Madrid
# 2          A. Robben       32.0  Netherlands   FC Bayern MÃ¼nchen
# 3    Z. IbrahimoviÄ‡       34.0       Sweden  Paris Saint-Germain
# 4           M. Neuer        NaN      Germany   FC Bayern MÃ¼nchen

# %%
player_defending.sort_values(by=['defending'], ascending=False).head()
# Out:
#       short_name  defending nationality                 club
# 15  Thiago Silva       90.0      Brazil  Paris Saint-Germain
# 21    M. Hummels       88.0     Germany    Borussia Dortmund
# 49    M. Benatia       88.0     Morocco   FC Bayern MÃ¼nchen
# 13       P. Lahm       87.0     Germany   FC Bayern MÃ¼nchen
# 57  G. Chiellini       87.0       Italy             Juventus

# %%
real_madrid = fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['wage_eur'], ascending = False).head()
# Out:
#        sofifa_id                                         player_url  \
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 336       193041  https://sofifa.com/player/193041/keylor-navas/...
# 11084     219914  https://sofifa.com/player/219914/guillermo-var...
# 10655     211234  https://sofifa.com/player/211234/enzo-alan-zid...
# 9350      209960  https://sofifa.com/player/209960/fernando-pach...
#
#               short_name                            long_name  age        dob  \
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29 1985-02-05
# 336             K. Navas                         Keylor Navas   27 1986-12-15
# 11084          G. Varela                     Guillermo Varela   21 1993-03-24
# 10655    Enzo FernÃ¡ndez          Enzo Alan Zidane FernÃ¡ndez   19 1995-03-24
# 9350             Pacheco              Fernando Pacheco Flores   22 1992-05-18
#
#        height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 1            185         80    Portugal  Real Madrid  ...  63+3  63+3  63+3
# 336          185         78  Costa Rica  Real Madrid  ...   NaN   NaN   NaN
# 11084        171         69     Uruguay  Real Madrid  ...  58+0  54+0  54+0
# 10655        186         75       Spain  Real Madrid  ...  46+0  44+0  44+0
# 9350         187         82       Spain  Real Madrid  ...   NaN   NaN   NaN
#
#         rdm   rwb    lb   lcb    cb   rcb    rb
# 1      63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 336     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11084  54+0  58+0  60+0  63+0  63+0  63+0  60+0
# 10655  44+0  46+0  38+0  34+0  34+0  34+0  38+0
# 9350    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['shooting'], ascending = False).head()
# Out:
#      sofifa_id                                         player_url  \
# 1        20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 34      165153  https://sofifa.com/player/165153/karim-benzema...
# 11      173731  https://sofifa.com/player/173731/gareth-bale/1...
# 33      182521  https://sofifa.com/player/182521/toni-kroos/15...
# 173     178224  https://sofifa.com/player/178224/javier-hernan...
#
#             short_name                            long_name  age        dob  \
# 1    Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29 1985-02-05
# 34          K. Benzema                        Karim Benzema   26 1987-12-19
# 11             G. Bale                    Gareth Frank Bale   24 1989-07-16
# 33            T. Kroos                           Toni Kroos   24 1990-01-04
# 173      J. HernÃ¡ndez          Javier HernÃ¡ndez BalcÃ¡zar   26 1988-06-01
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 1          185         80    Portugal  Real Madrid  ...  63+3  63+3  63+3
# 34         184         79      France  Real Madrid  ...  58+2  58+2  58+2
# 11         183         74       Wales  Real Madrid  ...  76+2  75+2  75+2
# 33         182         78     Germany  Real Madrid  ...  74+2  76+2  76+2
# 173        175         71      Mexico  Real Madrid  ...  54+1  53+1  53+1
#
#       rdm   rwb    lb   lcb    cb   rcb    rb
# 1    63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 34   58+2  58+2  53+2  49+2  49+2  49+2  53+2
# 11   75+2  76+2  74+2  70+2  70+2  70+2  74+2
# 33   76+2  74+2  68+2  63+2  63+2  63+2  68+2
# 173  53+1  54+1  51+1  46+1  46+1  46+1  51+1
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['defending'], ascending = False).head()
# Out:
#      sofifa_id                                         player_url  \
# 14      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 81      120533  https://sofifa.com/player/120533/kepler-lavera...
# 50      179846  https://sofifa.com/player/179846/sami-khedira/...
# 152     201535  https://sofifa.com/player/201535/raphael-varan...
# 371     146741  https://sofifa.com/player/146741/alvaro-arbelo...
#
#        short_name                      long_name  age        dob  height_cm  \
# 14   Sergio Ramos           Sergio Ramos GarcÃ­a   28 1986-03-30        183
# 81           Pepe  KÃ©pler Laveran Lima Ferreira   31 1983-02-26        188
# 50     S. Khedira                   Sami Khedira   27 1987-04-04        189
# 152     R. Varane                RaphaÃ«l Varane   21 1993-04-25        191
# 371       Arbeloa           Ãlvaro Arbeloa Coca   31 1983-01-17        184
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 14          75       Spain  Real Madrid  ...  81+2  80+2  80+2  80+2  81+2
# 81          81    Portugal  Real Madrid  ...  72+1  73+1  73+1  73+1  72+1
# 50          85     Germany  Real Madrid  ...  77+1  83+1  83+1  83+1  77+1
# 152         78      France  Real Madrid  ...  72+1  76+1  76+1  76+1  72+1
# 371         79       Spain  Real Madrid  ...  76+1  75+1  75+1  75+1  76+1
#
#        lb   lcb    cb   rcb    rb
# 14   84+2  85+2  85+2  85+2  84+2
# 81   77+1  82+1  82+1  82+1  77+1
# 50   79+1  81+1  81+1  81+1  79+1
# 152  76+1  80+1  80+1  80+1  76+1
# 371  78+1  77+1  77+1  77+1  78+1
#
# [5 rows x 104 columns]

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain         17
# Portugal       3
# Germany        2
# France         2
# Brazil         2
# Wales          1
# Croatia        1
# Colombia       1
# Mexico         1
# Costa Rica     1
# Finland        1
# Uruguay        1
# Name: nationality, dtype: int64
